# %% [markdown]
# # <img src="https://github.com/JuliaLang/julia-logo-graphics/raw/master/images/julia-logo-color.png" height="100" /> _Colab Notebook Template_
#
# ## Instructions
# 1. Work on a copy of this notebook: _File_ > _Save a copy in Drive_.
# 2. If you need a GPU: _Runtime_ > _Change runtime type_ > _Harware accelerator_ = _GPU_.
# 3. Execute the following cell to install Julia, IJulia and other packages (update `JULIA_VERSION` and `JULIA_PACKAGES*` if needed). This takes a couple of minutes.
# 4. Reload this page and continue to the next section.
#
# _Notes_:
# * If your Colab Runtime gets reset (e.g., due to inactivity), repeat steps 3 and 4.
# * If you want to change the Julia version or activate/deactivate the GPU, you will need to reset the Runtime: _Runtime_ > _Factory reset runtime_ and repeat steps 3 and 4.

# %%
%%shell
set -e

#---------------------------------------------#
JULIA_VERSION="1.4.2" # any version ≥ 0.7.0
JULIA_PACKAGES="IJulia BenchmarkTools"
JULIA_PACKAGES_IF_GPU="CuArrays"
#---------------------------------------------#

if [ -n "$COLAB_GPU" ] && [ -z `which julia` ]; then
  # Install Julia
  JULIA_VER=`cut -d '.' -f -2 <<< "$JULIA_VERSION"`
  echo "Installing Julia $JULIA_VERSION on the current Colab Runtime..."
  BASE_URL="https://julialang-s3.julialang.org/bin/linux/x64"
  URL="$BASE_URL/$JULIA_VER/julia-$JULIA_VERSION-linux-x86_64.tar.gz"
  wget -nv $URL -O /tmp/julia.tar.gz # -nv means "not verbose"
  tar -x -f /tmp/julia.tar.gz -C /usr/local --strip-components 1
  rm /tmp/julia.tar.gz

  # Install Packages
  if [ "$COLAB_GPU" = "1" ]; then
      JULIA_PACKAGES="$JULIA_PACKAGES $JULIA_PACKAGES_IF_GPU"
  fi
  for PKG in `echo $JULIA_PACKAGES`; do
    echo "Installing Julia package $PKG..."
    julia -e 'using Pkg; pkg"add '$PKG'; precompile;"'
  done

  # Rename kernel to "julia"
  echo "Renaming kernel to 'julia'..."
  KERNEL_DIR=`julia -e "using IJulia; print(IJulia.kerneldir())"`
  KERNEL_NAME=`ls -d "$KERNEL_DIR"/julia*`
  mv -f $KERNEL_NAME "$KERNEL_DIR"/julia  

  echo ''
  echo "Success! Please reload this page and jump to the next section."
fi
# Out:
# Installing Julia 1.4.2 on the current Colab Runtime...
# 2020-06-23 10:28:46 URL:https://storage.googleapis.com/julialang2/bin/linux/x64/1.4/julia-1.4.2-linux-x86_64.tar.gz [99093958/99093958] -> "/tmp/julia.tar.gz" [1]
# Installing Julia package IJulia...
#     Cloning default registries into `~/.julia`
#     Cloning registry from "https://github.com/JuliaRegistries/General.git"
#       Added registry `General` to `~/.julia/registries/General`
#   Resolving package versions...
#   Installed SoftGlobalScope ─ v1.0.10
#   Installed VersionParsing ── v1.2.0
#   Installed MbedTLS_jll ───── v2.16.0+2
#   Installed ZeroMQ_jll ────── v4.3.2+4
#   Installed Parsers ───────── v1.0.5
#   Installed Conda ─────────── v1.4.1
#   Installed JSON ──────────── v0.21.0
#   Installed IJulia ────────── v1.21.2
#   Installed ZMQ ───────────── v1.2.1
#   Installed MbedTLS ───────── v1.0.2
# ...
# ######################################################################## 100.0%
# ...

# %% [markdown]
# # Checking the Installation
# The `versioninfo()` function should print your Julia version and some other info about the system:

# %%
versioninfo()
# Out:
# Julia Version 1.4.2
# Commit 44fa15b150* (2020-05-23 18:35 UTC)
# Platform Info:
#   OS: Linux (x86_64-pc-linux-gnu)
#   CPU: Intel(R) Xeon(R) CPU @ 2.20GHz
#   WORD_SIZE: 64
#   LIBM: libopenlibm
#   LLVM: libLLVM-8.0.1 (ORCJIT, broadwell)

# %%
using BenchmarkTools

M = rand(2048, 2048)
@benchmark M^2
# Out:
# BenchmarkTools.Trial:
#   memory estimate:  32.00 MiB
#   allocs estimate:  2
#   --------------
#   minimum time:     537.678 ms (0.12% GC)
#   median time:      544.081 ms (0.00% GC)
#   mean time:        558.553 ms (2.55% GC)
#   maximum time:     654.883 ms (16.48% GC)
#   --------------
#   samples:          9
#   evals/sample:     1

# %%
if ENV["COLAB_GPU"] == "1"
    using CuArrays

    M_gpu = cu(M)
    @benchmark CuArrays.@sync M_gpu^2
else
    println("No GPU found.")
end
# Out:
# No GPU found.

# %% [markdown]
# # Need Help?
#
# * Learning: https://julialang.org/learning/
# * Documentation: https://docs.julialang.org/
# * Questions & Discussions:
#   * https://discourse.julialang.org/
#   * http://julialang.slack.com/
#   * https://stackoverflow.com/questions/tagged/julia
#
# If you ever ask for help or file an issue about Julia, you should generally provide the output of `versioninfo()`.

# %% [markdown]
# Have fun!
#
# <img src="https://raw.githubusercontent.com/JuliaLang/julia-logo-graphics/master/images/julia-logo-mask.png" height="100" />
